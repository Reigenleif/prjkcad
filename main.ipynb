# %%
from utils import TrainModelPipeline
from IPython.display import clear_output
# Out:
# /home/alief/miniconda3/envs/kaggle/lib/python3.12/site-packages/sklearn/utils/_param_validation.py:14: UserWarning: A NumPy version >=1.22.4 and <2.3.0 is required for this version of SciPy (detected version 2.4.6)
#   from scipy.sparse import csr_matrix, issparse

# %%
# Experiment 1
configs = [
    "configs/experiment_1a.yaml",
    "configs/experiment_1b.yaml",
    "configs/experiment_1c.yaml",
    "configs/experiment_1d.yaml",
]

for config in configs:
    pl = TrainModelPipeline(config)
    pl.train_model()
    clear_output()
    pl.plot_progression()

# %%
# Experiment 2
configs = [
    "configs/experiment_2a.yaml",
    "configs/experiment_2b.yaml",
    "configs/experiment_2c.yaml",
]

for config in configs:
    pl = TrainModelPipeline(config)
    pl.train_model()
    pl.plot_progression()
# Out:
# Loading CSV from: /home/alief/prjkcad/data/text2cad/text2cad_v1.1.csv
# Processing 100000 rows to load JSON payloads...
# ...
# 100%|██████████| 100000/100000 [00:05<00:00, 17125.47it/s]
# Successfully created 99956/100000 DualSeq instances.
# Sampled 999 instances from the dataset based on the specified sample ratio of 0.01.
# Loading weights:   0%|          | 0/131 [00:00<?, ?it/s]
# Starting training for 200 epochs with quantization: fp16. Model parameters: 102,308,652
# ...
# Eval 200/200: 100%|██████████| 13/13 [00:02<00:00,  4.83it/s]
# Loading CSV from: /home/alief/prjkcad/data/text2cad/text2cad_v1.1.csv
# Processing 100000 rows to load JSON payloads...
# ...
# 100%|██████████| 100000/100000 [00:06<00:00, 16338.73it/s]
# Successfully created 99956/100000 DualSeq instances.
# Sampled 9995 instances from the dataset based on the specified sample ratio of 0.1.
# Loading weights:   0%|          | 0/131 [00:00<?, ?it/s]
# Model loaded from out/experiment_2a/checkpoint.pt
# ...
